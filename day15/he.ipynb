# %%
import tenseal as ts
import numpy as np

# %%
# Setup TenSEAL context
context = ts.context(
    ts.SCHEME_TYPE.CKKS,
    poly_modulus_degree=8192,
    coeff_mod_bit_sizes=[60, 40, 40, 60]
)
context.generate_galois_keys()
context.global_scale = 2**40

# %%
context_share = context.copy()

# %%
context_share.make_context_public()  # Removes secret key from context

# %%
context

# %%
context_share

# %%
v1 = np.random.randint(0, 10, 10)
v2 = np.random.randint(0, 10, 10)
v1, v2
# Out:
# (array([4, 9, 2, 6, 3, 3, 6, 5, 5, 1]), array([9, 4, 7, 0, 5, 5, 2, 6, 3, 5]))

# %%
# encrypted vectors
enc_v1 = ts.ckks_vector(context, v1)
enc_v2 = ts.ckks_vector(context, v2)

# %%
print(enc_v1.serialize().hex())
print(enc_v2.serialize().hex())
# Out:
# ...
# ...

# %%
result = enc_v1 + enc_v2
result.decrypt()
# Out:
# [2.0000000002936478,
#  1.99999999974749,
#  12.000000000615618,
#  10.000000000919533,
#  -1.5398180508441328e-09,
#  3.0000000032910856,
#  7.999999999620011,
#  12.000000006377775,
#  16.00000000025292,
#  12.99999999776766]

# %%
context.s
result.decrypt()  # ~ [4, 4, 4, 4, 4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 context.s
#       2 result.decrypt()
#
# AttributeError: 'Context' object has no attribute 's'

# %%
result = enc_v1.dot(enc_v2)
result.decrypt() # ~ [10]
# Out:
# [262.0000350918975]
